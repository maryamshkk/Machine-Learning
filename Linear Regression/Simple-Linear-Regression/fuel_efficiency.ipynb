# %%
# Imports
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %%
# Data
x = np.array([3.5,3.69,3.44,3.43,4.34,4.42,2.37])
y = np.array([18,15,18,16,15,14,24])

# %%
# Reshape x for sklearn (2D)
x = x.reshape(-1,1)

# %%
# Slope m 
n = len(x)
numer = (n * np.sum(x*y) - np.sum(x) * np.sum(y))
denom = (n * np.sum(x**2) - (np.sum(x))**2)
m = numer / denom
print(m)
# Out:
# 923.5375590679464

# %%
# Intercept c
c = (np.sum(y) - m * np.sum(X)) / n
print(c)
# Out:
# -3306.273016131653

# %%
# X_new = 4.0
# Y_new = m * X_new + c
# print(f'Equation: Y={m:.4f}X +{c:.4f}')
# print(f'Y:{Y_new:.4f}')

# %%
# Slope
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
x_pred = np.array([[4.0]])
y_pred = model.predict(X_pred)
print(f'Predicted MPG for 4000-pounds car: {y_pred[0]:.2f}')
# Out:
# Predicted MPG for 4000-pounds car: 15.31

# %%
# Plot
plt.figure(figsize=(10,5))
plt.scatter(X,y, color='blue', label='Data Points')
plt.plot(x, model.predict(x), color='red', label='Regression line')
plt.scatter(X_new, Y_new, color='green', label='Prediction (400 lbs)')

plt.xlabel('Pounds in (1000s of pounds)')
plt.ylabel('Miles per Gallon (MPG)')
plt.title('Linear Regression: Car weight vs .MPG')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Multiple Linear Regression
